# %% [markdown]
# ## Get the data in terms of Na

# %%
mu=1.5E-8
Ls=9728061

Na_fromSim={}

for i in syn_theta_data: 
    Na_fromSim_replicate={k:(v/(4*Ls*mu)) for k,v in syn_theta_data[i].items()}
    Na_fromSim[i]=Na_fromSim_replicate

# %%
Ncurr_data={}

for condition in Na_fromSim:
    Ncurr_data[condition]={}
    for replicate_id in Na_fromSim[condition]: 
        Na=Na_fromSim[condition][replicate_id]
        fold_expansion=dem_parameteres_data[condition][replicate_id][0]
        Ncurr=Na*fold_expansion
        Ncurr_data[condition][replicate_id]=Ncurr
        #print(Ncurr)

# %%
#Build a dataframe for the data for plotting
df_rows=[] #row of the format condition, type(either Na or Ncurr), replicate_id, N_value

for condition in Na_fromSim:
    new_rows=[[condition, 'Na', replicate_id, Nvalue, best_model_data[condition][replicate_id]] for replicate_id,Nvalue in Na_fromSim[condition].items()]
    df_rows=df_rows+new_rows
    
for condition in Ncurr_data: 
    new_rows=[[condition, 'Ncurr', replicate_id, Nvalue, best_model_data[condition][replicate_id]] for replicate_id,Nvalue in Ncurr_data[condition].items()]
    df_rows=df_rows+new_rows
    
N_dataframe=pd.DataFrame(df_rows, columns=['Condition', 'Timepoint', 'Replicate_id', 'N_Value', 'Model'])

# %% [markdown]
# ## Compute Time in terms of generations

# %%
# The time T is in terms of 2*Na. To get generations, multiply T by 2*Na
dem_parameteres_generations_data={}
t_values=[]

for condition in dem_parameteres_data:
    dem_parameteres_generations_data[condition]={}
    
    for replicate_id in dem_parameteres_data[condition]:
        Na=syn_theta_data[condition][replicate_id]
        model=best_model_data[condition][replicate_id]
        
        #For the OneEpoch, there is no time change to be calculated
        if model=='OneEpoch':
            new_nu=dem_parameteres_data[condition][replicate_id][0]
            new_t=0
            dem_parameteres_generations_data[condition][replicate_id]=[new_nu, new_t]
            
        elif model=='TwoEpoch':
            new_nu=dem_parameteres_data[condition][replicate_id][0]
            old_t=dem_parameteres_data[condition][replicate_id][1]
            new_t=old_t*Na*2
            t_values.append(new_t)
            dem_parameteres_generations_data[condition][replicate_id]=[new_nu, new_t]
            

max_t_value=max(t_values)
max(t_values)
# Out:
# 40660.10671457891

# %%
#dem_parameteres_generations_data

# %% [markdown]
# # Draft Figure 1

# %%
sbn.pointplot(data=N_dataframe, x="Timepoint", y="N_Value", hue="Condition", dodge=True)
# Out:
# <AxesSubplot:xlabel='Timepoint', ylabel='N_Value'>

# %%
sbn.lineplot(data=N_dataframe, x="Timepoint", y="N_Value", hue="Condition")
# Out:
# <AxesSubplot:xlabel='Timepoint', ylabel='N_Value'>

# %%
#Subset to Neutral observations
N_neutral=N_dataframe[N_dataframe['Condition']=='Neutral']

# %%
N_neutral
# Out:
#     Condition Timepoint Replicate_id       N_Value     Model
# 0     Neutral        Na            1   9886.916411  OneEpoch
# 1     Neutral        Na            2   9730.263833  TwoEpoch
# 2     Neutral        Na            3   9066.895526  TwoEpoch
# 3     Neutral        Na            4   9510.397058  TwoEpoch
# 4     Neutral        Na            5   9825.363109  OneEpoch
# 5     Neutral        Na            6   9865.405848  OneEpoch
# 6     Neutral        Na            7   9898.829953  OneEpoch
# 7     Neutral        Na            8   9884.268957  OneEpoch
# 8     Neutral        Na            9   9332.274769  TwoEpoch
# 9     Neutral        Na           10   9815.435157  OneEpoch
# 10    Neutral        Na           11   9747.594152  OneEpoch
# 11    Neutral        Na           12   9554.366063  TwoEpoch
# 12    Neutral        Na           13   9636.714399  TwoEpoch
# 13    Neutral        Na           14   9765.133533  OneEpoch
# ...

# %%
#Make the grid plot
fig, axs = plt.subplots(1, 7, sharey=True, figsize=[35,10])
plt.rcParams['font.size'] = '25'
fig.subplots_adjust(wspace=0.1)

#Specify the order of plots and the colors of the plots
order_plotting=['Neutral', 'E5', 'E4', 'E3', 'E5_Partial', 'E4_Partial', 'E3_Partial']
color_conditions={'SLiM_True_DFE':'#99b3ff', 'Neutral':'#3366ff', 'E5':'#267326', 'E4':'#9bc238',
                  'E3': '#7D2FB9', 'E5_Partial':'#cc0000' ,'E3_Partial':'#E6BE00', 
                  'E4_Partial':'#ff6600'}

title_conditions={'SLiM_True_DFE':'True model', 'Neutral':'s=0', 'E5':'s=1e-05', 'E4':'s=1e-4',
                  'E3': 's=1e-3', 'E5_Partial':'22% at s=1e-05' ,'E3_Partial':'22% at s=1e-03', 
                  'E4_Partial':'22% at s=1e-04'}

model_tips={'OneEpoch':'o', 'TwoEpoch':'X'}

i=0
for condition in order_plotting:
    ax_current=axs[i]
    color_current=color_conditions[condition]
    title_current=title_conditions[condition]
    #Subset the dataframe to the condition values
    N_subset=N_dataframe[N_dataframe['Condition']==condition]
    
    #Make the subplot
    sbn.lineplot(data=N_subset, x="Timepoint", y="N_Value", estimator=None, units='Replicate_id', ax=ax_current, color=color_current, lw=2)
    sbn.scatterplot(data=N_subset, x="Timepoint", y="N_Value", style='Model', ax=ax_current, color=color_current, s=70, markers=model_tips, legend=False) #marker='.'
    i=i+1
    
    ax_current.set_xlabel('')
    ax_current.set_title(title_current, fontsize=30)
    ax_current.tick_params(axis='x', rotation=60)


axs[0].text(0.01, 10050, '*', size=25)
plt.ylim(0,10500)
#plt.xlabel("Gamma ranges")
axs[0].set_ylabel("Population Size Value")
#plt.title("Discretized DFE in terms of gamma, or 2sNa")
# Out:
# Text(0, 0.5, 'Population Size Value')

# %%
#Make the grid plot
fig, axs = plt.subplots(1, 7, sharey=True, figsize=[34,10])
plt.rcParams['font.size'] = '25'
fig.subplots_adjust(wspace=0.1)

#Specify the order of plots and the colors of the plots
order_plotting=['Neutral', 'E5', 'E4', 'E3', 'E5_Partial', 'E4_Partial', 'E3_Partial']
color_conditions={'SLiM_True_DFE':'#99b3ff', 'Neutral':'#3366ff', 'E5':'#267326', 'E4':'#9bc238',
                  'E3': '#7D2FB9', 'E5_Partial':'#cc0000' ,'E3_Partial':'#E6BE00', 
                  'E4_Partial':'#ff6600'}

title_conditions={'SLiM_True_DFE':'True model', 'Neutral':'s=0', 'E5':'s=1e-05', 'E4':'s=1e-4',
                  'E3': 's=1e-3', 'E5_Partial':'22% at s=1e-05' ,'E3_Partial':'22% at s=1e-03', 
                  'E4_Partial':'22% at s=1e-04'}

i=0
for condition in order_plotting:
    ax_current=axs[i]
    color_current=color_conditions[condition]
    title_current=title_conditions[condition]
    #Subset the dataframe to the condition values
    N_subset=N_dataframe[N_dataframe['Condition']==condition]
    
    #Make the subplot
    sbn.lineplot(data=N_subset, x="Timepoint", y="N_Value", estimator=None, units='Replicate_id', ax=ax_current, color=color_current, lw=2)
    sbn.scatterplot(data=N_subset, x="Timepoint", y="N_Value", ax=ax_current, color=color_current, s=70) #marker='.'
    i=i+1
    
    ax_current.set_xlabel('')
    ax_current.set_title(title_current, fontsize=30)
    ax_current.tick_params(axis='x', rotation=60)
    ax_current.axhline(10000, color=color_conditions['SLiM_True_DFE'], ls='--', alpha=0.7, lw=3)

    
#axs[0].text(0.01, 10050, '*', size=25)
plt.ylim(0,10500)
#plt.xlabel("Gamma ranges")
axs[0].set_ylabel("Population Size Value")
# Out:
# Text(0, 0.5, 'Population Size Value')

# %%
#Make the grid plot
fig, axs = plt.subplots(1, 7, sharey=True, figsize=[35,10])
plt.rcParams['font.size'] = '25'
fig.subplots_adjust(wspace=0.1)

#Specify the order of plots and the colors of the plots
order_plotting=['Neutral', 'E5', 'E4', 'E3', 'E5_Partial', 'E4_Partial', 'E3_Partial']
color_conditions={'SLiM_True_DFE':'#99b3ff', 'Neutral':'#3366ff', 'E5':'#267326', 'E4':'#9bc238',
                  'E3': '#7D2FB9', 'E5_Partial':'#cc0000' ,'E3_Partial':'#E6BE00', 
                  'E4_Partial':'#ff6600'}

title_conditions={'SLiM_True_DFE':'True model', 'Neutral':'s=0', 'E5':'s=1e-05', 'E4':'s=1e-4',
                  'E3': 's=1e-3', 'E5_Partial':'22% at s=1e-05' ,'E3_Partial':'22% at s=1e-03', 
                  'E4_Partial':'22% at s=1e-04'}

model_tips={'OneEpoch':'o', 'TwoEpoch':'X'}

i=0
for condition in order_plotting:
    ax_current=axs[i]
    color_current=color_conditions[condition]
    title_current=title_conditions[condition]
    #Subset the dataframe to the condition values
    N_subset=N_dataframe[N_dataframe['Condition']==condition]
    
    #Make the subplot
    sbn.lineplot(data=N_subset, x="Timepoint", y="N_Value", estimator=None, units='Replicate_id', ax=ax_current, color=color_current, lw=2)
    sbn.scatterplot(data=N_subset, x="Timepoint", y="N_Value", style='Model', ax=ax_current, color=color_current, s=150, markers=model_tips, legend=False)
    i=i+1
    
    ax_current.set_xlabel('')
    ax_current.set_title(title_current, fontsize=30)
    ax_current.tick_params(axis='x', rotation=60)
    ax_current.axhline(10000, color=color_conditions['SLiM_True_DFE'], ls='--', alpha=0.7, lw=3)


#axs[0].text(0.01, 10050, '*', size=25)
plt.ylim(0,10500)
#plt.xlabel("Gamma ranges")
axs[0].set_ylabel("Population Size Value")
# Out:
# Text(0, 0.5, 'Population Size Value')

# %%
#Generate a custom legend
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

legend_elements = [Line2D([0], [0], marker= 'o', color='k', label='One Epoch Model', markersize=15),
                   Line2D([0], [0], marker='X', color='k', label='Two Epoch Model', markersize=15),]

# Create the figure
fig, ax = plt.subplots()
ax.legend(handles=legend_elements, loc='center')

plt.show()

# %% [markdown]
# ## Figure 1 with time included

# %% [markdown]
# ### Dataframe for plotting

# %%
#Build a dataframe for the data for plotting
df_rows=[] #row of the format condition, type(either Na or Ncurr), replicate_id, N_value

#Make the rows in terms of a real value
t_ancestral=-1*max_t_value-15 #Adding 15 to set an "ancestral" time

for condition in Na_fromSim:
    new_rows=[[condition, t_ancestral, replicate_id, Nvalue, best_model_data[condition][replicate_id]] for replicate_id,Nvalue in Na_fromSim[condition].items()]
    df_rows=df_rows+new_rows
    
    new_rows=[[condition, -1*dem_parameteres_generations_data[condition][replicate_id][1],replicate_id, Nvalue, best_model_data[condition][replicate_id]] for replicate_id,Nvalue in Na_fromSim[condition].items()]
    df_rows=df_rows+new_rows

for condition in Ncurr_data: 
    new_rows=[[condition, 0, replicate_id, Nvalue, best_model_data[condition][replicate_id]] for replicate_id,Nvalue in Ncurr_data[condition].items()]
    df_rows=df_rows+new_rows
    
    new_rows=[[condition, -1*dem_parameteres_generations_data[condition][replicate_id][1],replicate_id, Nvalue, best_model_data[condition][replicate_id]] for replicate_id,Nvalue in Ncurr_data[condition].items()]
    df_rows=df_rows+new_rows
    
N_dataframe=pd.DataFrame(df_rows, columns=['Condition', 'Timepoint', 'Replicate_id', 'N_Value', 'Model'])

# %%
N_dataframe[N_dataframe['Replicate_id']=='1']
# Out:
#       Condition     Timepoint Replicate_id       N_Value     Model
# 0       Neutral -40675.106715            1   9886.916411  OneEpoch
# 20      Neutral      0.000000            1   9886.916411  OneEpoch
# 40           E4 -40675.106715            1   2578.354022  TwoEpoch
# 60           E4  -9944.599644            1   2578.354022  TwoEpoch
# 80           E3 -40675.106715            1      3.349070  TwoEpoch
# 100          E3  -1231.529290            1      3.349070  TwoEpoch
# 120          E5 -40675.106715            1   9094.696758  TwoEpoch
# 140          E5  -5131.891215            1   9094.696758  TwoEpoch
# 160  E5_Partial -40675.106715            1   9227.991843  TwoEpoch
# 180  E5_Partial  -9190.345660            1   9227.991843  TwoEpoch
# 200  E3_Partial -40675.106715            1   7525.574007  TwoEpoch
# 220  E3_Partial  -1247.876438            1   7525.574007  TwoEpoch
# 240  E4_Partial -40675.106715            1   8230.168785  TwoEpoch
# ...

# %%
#Make the grid plot
fig, axs = plt.subplots(1, 7, sharey=True, figsize=[35,10])
plt.rcParams['font.size'] = '25'
fig.subplots_adjust(wspace=0.1)

#Specify the order of plots and the colors of the plots
order_plotting=['Neutral', 'E5', 'E4', 'E3', 'E5_Partial', 'E4_Partial', 'E3_Partial']
color_conditions={'SLiM_True_DFE':'#99b3ff', 'Neutral':'#3366ff', 'E5':'#267326', 'E4':'#9bc238',
                  'E3': '#7D2FB9', 'E5_Partial':'#cc0000' ,'E3_Partial':'#E6BE00', 
                  'E4_Partial':'#ff6600'}

title_conditions={'SLiM_True_DFE':'True model', 'Neutral':'100% at s=0', 'E5':'100% at s=1e-05', 'E4':'100% at s=1e-4',
                  'E3': '100% at s=1e-3', 'E5_Partial':'22% at s=1e-05' ,'E3_Partial':'22% at s=1e-03', 
                  'E4_Partial':'22% at s=1e-04'}

model_tips={'OneEpoch':'o', 'TwoEpoch':'X'}


i=0
for condition in order_plotting:
    ax_current=axs[i]
    color_current=color_conditions[condition]
    title_current=title_conditions[condition]
    #Subset the dataframe to the condition values
    N_subset=N_dataframe[N_dataframe['Condition']==condition]
    
    #Make the subplot
    sbn.lineplot(data=N_subset, x="Timepoint", y="N_Value", estimator=None, units='Replicate_id', ax=ax_current, color=color_current, lw=2)
    sbn.scatterplot(data=N_subset, x="Timepoint", y="N_Value", style='Model', ax=ax_current, color=color_current, s=150, markers=model_tips, legend=False) 
    i=i+1
    
    ax_current.set_xlabel('')
    ax_current.set_title(title_current, fontsize=30)
    ax_current.tick_params(axis='x', rotation=60)
    ax_current.axhline(10000, color=color_conditions['SLiM_True_DFE'], ls='--', alpha=0.7, lw=3)
    
    ax_current.set_xticklabels(['60000', '40000', '20000', '0', '20000'])


#axs[0].text(0.01, 10050, '*', size=25)
plt.ylim(-100,11000)
fig.supxlabel('Generations Ago', y=-0.1, fontsize=35)
axs[0].set_ylabel("Population Size Value", fontsize=35)

plt.savefig("/u/project/klohmuel/amzurita/Synonimous_Selection_Simulations/FigurePlots/Fig1_Dem.jpg", bbox_inches='tight', dpi=300)
# Out:
# /tmp/ipykernel_28130/54987081.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_current.set_xticklabels(['60000', '40000', '20000', '0', '20000'])
# /tmp/ipykernel_28130/54987081.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_current.set_xticklabels(['60000', '40000', '20000', '0', '20000'])
# /tmp/ipykernel_28130/54987081.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_current.set_xticklabels(['60000', '40000', '20000', '0', '20000'])
# /tmp/ipykernel_28130/54987081.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_current.set_xticklabels(['60000', '40000', '20000', '0', '20000'])
# /tmp/ipykernel_28130/54987081.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_current.set_xticklabels(['60000', '40000', '20000', '0', '20000'])
# ...

# %%
#Count the number of one epoch-two epoch fits
best_demo_model=pd.DataFrame(best_model_data)
best_demo_model
# Out:
#      Neutral        E4        E3        E5 E5_Partial E3_Partial E4_Partial
# 1   OneEpoch  TwoEpoch  TwoEpoch  TwoEpoch   TwoEpoch   TwoEpoch   TwoEpoch
# 2   TwoEpoch  TwoEpoch  TwoEpoch  TwoEpoch   OneEpoch   TwoEpoch   TwoEpoch
# 3   TwoEpoch  TwoEpoch  TwoEpoch  TwoEpoch   OneEpoch   TwoEpoch   TwoEpoch
# 4   TwoEpoch  TwoEpoch  TwoEpoch  TwoEpoch   TwoEpoch   TwoEpoch   TwoEpoch
# 5   OneEpoch  TwoEpoch  TwoEpoch  TwoEpoch   TwoEpoch   TwoEpoch   TwoEpoch
# 6   OneEpoch  TwoEpoch  TwoEpoch  TwoEpoch   TwoEpoch   TwoEpoch   TwoEpoch
# 7   OneEpoch  TwoEpoch  TwoEpoch  TwoEpoch   TwoEpoch   TwoEpoch   TwoEpoch
# 8   OneEpoch  TwoEpoch  TwoEpoch  TwoEpoch   OneEpoch   TwoEpoch   TwoEpoch
# 9   TwoEpoch  TwoEpoch  TwoEpoch  TwoEpoch   TwoEpoch   TwoEpoch   TwoEpoch
# 10  OneEpoch  TwoEpoch  TwoEpoch  TwoEpoch   OneEpoch   TwoEpoch   TwoEpoch
# 11  OneEpoch  TwoEpoch  TwoEpoch  TwoEpoch   OneEpoch   TwoEpoch   TwoEpoch
# ...

# %%
best_demo_model['Neutral'].value_counts()
# Out:
# OneEpoch    14
# TwoEpoch     6
# Name: Neutral, dtype: int64

# %%
best_demo_model['E5_Partial'].value_counts()
# Out:
# TwoEpoch    11
# OneEpoch     9
# Name: E5_Partial, dtype: int64

# %%
E4_Partial={'1': [1.1905445, 1.12636637], '2': [1.22722104, 0.95638147], '3': [1.185057, 0.90597148], '4': [1.16486615, 0.25984262], '5': [1.33310678, 1.47361452], '6': [1.17227746, 0.40753928], '7': [1.20186344, 0.60478158], '8': [1.19723452, 0.64216093], '9': [1.20578806, 0.52223111], '10': [1.28454617, 1.35435759], '11': [1.1635094, 0.36294994], '12': [1.21665942, 0.91976074], '13': [1.16468097, 0.26190182], '14': [1.1860784, 0.66352679], '15': [1.25546742, 1.22241915], '16': [1.3433663, 1.70609019], '17': [1.14200731, 0.4852324], '18': [1.21006491, 1.02548652], '19': [1.17898362, 1.04346782], '20': [1.21289008, 1.03369974]}

# %%
fold_expansion_E4_Partial=[]
for i in E4_Partial.values():
    fold_expansion_E4_Partial.append(i[0])

# %%
np.mean(fold_expansion_E4_Partial)/1
# Out:
# 1.2118106475000001

# %%
dem_parameteres_data
# Out:
# {'Neutral': {'1': [1, 0.08765266],
#   '2': [1.06516429, 0.0391106],
#   '3': [1.10022186, 1.18973944],
#   '4': [1.05108107, 0.29506982],
#   '5': [1, 0.1971096],
#   '6': [1, 0.17316056],
#   '7': [1, 0.07390356],
#   '8': [1, 0.15124155],
#   '9': [1.08650555, 0.56569708],
#   '10': [1, 0.06916131],
#   '11': [1, 0.16868378],
#   '12': [1.06628421, 0.06982354],
#   '13': [1.04215638, 0.26047733],
#   '14': [1, 0.17251793],
#   '15': [1, 0.11403045],
#   '16': [1, 0.13025698],
#   '17': [1, 0.11521382],
#   '18': [1, 0.16940997],
#   '19': [1, 0.14999255],
#   '20': [1, 0.06878799]},
#  'E4': {'1': [3.76849918, 3.30397859],
#   '2': [3.27970212, 2.66949618],
#   '3': [3.96809831, 3.5006403],
#   '4': [3.38739635, 2.63336452],
#   '5': [3.06913072, 2.13816009],
#   '6': [2.80570891, 2.07112085],
#   '7': [3.12976773, 2.49335785],
#   '8': [2.73293596, 1.87607673],
#   '9': [3.59471848, 2.95357472],
#   '10': [3.65549983, 3.04475954],
#   '11': [3.5482102, 3.0349855],
# ...
